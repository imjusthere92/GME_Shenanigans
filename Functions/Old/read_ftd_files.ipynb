# %%
import pandas as pd

from pathlib import Path
import csv

# %%
data = pd.read_csv(
    Path("Resources/sec_ftd_1.csv"),
    index_col=False
)
data.head()
# Out:
#   SETTLEMENT DATE|CUSIP|SYMBOL|QUANTITY (FAILS)|DESCRIPTION|PRICE
# 0  20210816|B38564108|EURN|33389|EURONAV NV ANTWE...
# 1  20210816|C00948106|AGRI|7719|AGRIFORCE GROWING...
# 2  20210816|D18190898|DB|66551|DEUTSCHE BANK AG N...
# 3  20210816|G0R21B112|ACTDW|495|ARCLIGHT CLEAN TR...
# 4  20210816|G00748114|STWOW|3700|ACON S2 ACQUISIT...

# %%
#data.rename(columns={header:'SETTLEMENT_DATE,CUSIP,SYMBOL,QUANTITY_FAILS,DESCRIPTION,PRICE'},inplace=True)
header = "SETTLEMENT DATE|CUSIP|SYMBOL|QUANTITY (FAILS)|DESCRIPTION|PRICE"
data[header] = data[header].str.replace('|',',')
new_data = data.rename(columns={header:'SETTLEMENT_DATE,CUSIP,SYMBOL,QUANTITY_FAILS,DESCRIPTION,PRICE'})
Header = "Header"
new_data = data.rename(columns={header:Header})
new_data
# Out:
# C:\Users\watso\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                   Header
# 0      20210816,B38564108,EURN,33389,EURONAV NV ANTWE...
# 1      20210816,C00948106,AGRI,7719,AGRIFORCE GROWING...
# 2      20210816,D18190898,DB,66551,DEUTSCHE BANK AG N...
# 3      20210816,G0R21B112,ACTDW,495,ARCLIGHT CLEAN TR...
# 4      20210816,G00748114,STWOW,3700,ACON S2 ACQUISIT...
# ...                                                  ...
# 67686  20210831,98986M103,ZYXI,3367,ZYNEX, INC. COMMO...
# 67687  20210831,98986T108,ZNGA,12398,ZYNGA INC CLASS ...
# 67688  20210831,98986X109,ZYNE,506,ZYNERBA PHARMACEUT...
# 67689                         Trailer record count 67689
# 67690        Trailer total quantity of shares 1978777078
#
# [67691 rows x 1 columns]

# %%
new_df = pd.DataFrame()
new_df = new_data.Header.str.split(",",expand=True)
new_df
# Out:
#                                                  0          1      2      3  \
# 0                                         20210816  B38564108   EURN  33389
# 1                                         20210816  C00948106   AGRI   7719
# 2                                         20210816  D18190898     DB  66551
# 3                                         20210816  G0R21B112  ACTDW    495
# 4                                         20210816  G00748114  STWOW   3700
# ...                                            ...        ...    ...    ...
# 67686                                     20210831  98986M103   ZYXI   3367
# 67687                                     20210831  98986T108   ZNGA  12398
# 67688                                     20210831  98986X109   ZYNE    506
# 67689                   Trailer record count 67689       None   None   None
# 67690  Trailer total quantity of shares 1978777078       None   None   None
#
#                                     4                         5      6     7
# 0      EURONAV NV ANTWERPEN (BELGIUM)                      7.75   None  None
# 1      AGRIFORCE GROWING SYS LTD COM                       2.89   None  None
# 2      DEUTSCHE BANK AG NAMEN AKT (DE                     12.96   None  None
# 3      ARCLIGHT CLEAN TRANSITION CORP                      1.12   None  None
# 4      ACON S2 ACQUISITION CORP WT EX                      1.39   None  None
# ...                               ...                       ...    ...   ...
# 67686                           ZYNEX   INC. COMMON STOCK (NV)   13.38  None
# 67687               ZYNGA INC CLASS A                      8.88   None  None
# 67688  ZYNERBA PHARMACEUTICALS INC CO                      4.11   None  None
# 67689                            None                      None   None  None
# 67690                            None                      None   None  None
#
# [67691 rows x 8 columns]

# %%
new_df = new_df.rename(columns={0:'Date',1:'CUSIP',2:'SYMBOL',3:'QUANTITY_FAILS',4:'DESCRIPTION',5:'PRICE'})
new_df
# Out:
#                                               Date      CUSIP SYMBOL  \
# 0                                         20210816  B38564108   EURN
# 1                                         20210816  C00948106   AGRI
# 2                                         20210816  D18190898     DB
# 3                                         20210816  G0R21B112  ACTDW
# 4                                         20210816  G00748114  STWOW
# ...                                            ...        ...    ...
# 67686                                     20210831  98986M103   ZYXI
# 67687                                     20210831  98986T108   ZNGA
# 67688                                     20210831  98986X109   ZYNE
# 67689                   Trailer record count 67689       None   None
# 67690  Trailer total quantity of shares 1978777078       None   None
#
#       QUANTITY_FAILS                     DESCRIPTION  \
# 0              33389  EURONAV NV ANTWERPEN (BELGIUM)
# 1               7719  AGRIFORCE GROWING SYS LTD COM
# 2              66551  DEUTSCHE BANK AG NAMEN AKT (DE
# 3                495  ARCLIGHT CLEAN TRANSITION CORP
# 4               3700  ACON S2 ACQUISITION CORP WT EX
# ...              ...                             ...
# 67686           3367                           ZYNEX
# 67687          12398               ZYNGA INC CLASS A
# 67688            506  ZYNERBA PHARMACEUTICALS INC CO
# 67689           None                            None
# 67690           None                            None
#
#                           PRICE      6     7
# 0                          7.75   None  None
# 1                          2.89   None  None
# 2                         12.96   None  None
# 3                          1.12   None  None
# 4                          1.39   None  None
# ...                         ...    ...   ...
# 67686   INC. COMMON STOCK (NV)   13.38  None
# 67687                      8.88   None  None
# 67688                      4.11   None  None
# 67689                      None   None  None
# 67690                      None   None  None
#
# [67691 rows x 8 columns]
